# %% [markdown]
# # I : Notebook Inference

# %% [markdown]
# ### I / A : Import libraries

# %%
import pandas as pd
import numpy as np
import statsmodels.api as sm
import statsmodels.formula.api as smf

# %% [markdown]
# ### I / B : Importing our data

# %%
inference_df = pd.read_csv('data/eda_clean_df.csv')
inference_df
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -119.84     36.77                 6.0       1853.0           473.0
# 1        -117.80     33.68                 8.0       2032.0           349.0
# 2        -120.19     36.60                25.0        875.0           214.0
# 3        -118.32     34.10                31.0        622.0           229.0
# 4        -121.23     37.79                21.0       1922.0           373.0
# ...          ...       ...                 ...          ...             ...
# 16331    -121.90     39.59                20.0       1465.0           278.0
# 16332    -122.25     38.11                49.0       2365.0           504.0
# 16333    -121.22     38.92                19.0       2531.0           461.0
# 16334    -118.14     34.16                39.0       2776.0           840.0
# 16335    -124.13     40.80                31.0       2152.0           462.0
#
# ...

# %% [markdown]
# ### I / C : Linear Regression using statsmodel

# %%
inference_drop = inference_df.loc[:, inference_df.columns != 'ocean_proximity']
# inference_drop

# %%
X = inference_drop.loc[:, inference_drop.columns != 'median_house_value']
y = inference_df.loc[:, inference_df.columns == 'median_house_value']

# %%
X = sm.add_constant(X)
model = sm.OLS(y, X)

# %%
results = model.fit()
results.params
# Out:
# const   -3.552297e+06
# x1      -4.236583e+04
# x2      -4.224067e+04
# x3       1.156387e+03
# x4      -8.462532e+00
# x5       1.110395e+02
# x6      -3.782387e+01
# x7       5.148473e+01
# x8       4.039426e+04
# dtype: float64

# %%
print(results.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:     median_house_value   R-squared:                       0.638
# Model:                            OLS   Adj. R-squared:                  0.638
# Method:                 Least Squares   F-statistic:                     3593.
# Date:                Wed, 22 Sep 2021   Prob (F-statistic):               0.00
# Time:                        19:33:12   Log-Likelihood:            -2.0528e+05
# No. Observations:               16336   AIC:                         4.106e+05
# Df Residuals:                   16327   BIC:                         4.106e+05
# Df Model:                           8
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const      -3.552e+06   7.03e+04    -50.548      0.000   -3.69e+06   -3.41e+06
# ...
